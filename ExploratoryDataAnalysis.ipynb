# %% [markdown]
# <a href="https://colab.research.google.com/github/andreavazquezt/ProyectoIntegrador/blob/main/ExploratoryDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Comenzamos importando las librebrias que utilizaremos para el desarrollo del codigo
# ```

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Cargamos un data set de prueba para practicar con las herramientas de EDA

# %%
df = pd.read_csv("/content/drive/MyDrive/world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %% [markdown]
# Visualizamos la informacion a nivel general del data set, como el numero de columnas, el nombre, los valores y el tipo de datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %% [markdown]
# Visualizamos la informacion por columnas con el siguiente comando

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %% [markdown]
# Para poder descartar los valores faltantes y evitar que cambien nuestro conjunto de datos, utilizamos el siguiente comando para ubicarlos y asi poder ejecutar la estrategia correspondiente y ajustar nuestro dataset. Lo cual es especificamente tratamos de hacer durante el Exploratory Data Analysis, encontrar valores faltantes, valores atipicos en otras palabras, cosas que esten mal con nuestro dataset o inclusive encontrar diversas perspectivas dentro de la misma busqueda.

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %% [markdown]
# Para poder visualizar los valores unicos de cada columna utilizaremos el siguiente comando

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %% [markdown]
# Para ordenar de manera ascendente nuestros datos podemos utilizar el siguiente comando, para efectos del ejemplo demostraremos solo para las primeras 5 filas del dataset y para la columna de 2022 Population:

# %%
df.sort_values(by="2022 Population").head()
# Out:
#      Rank CCA3           Country       Capital      Continent  \
# 226   234  VAT      Vatican City  Vatican City         Europe
# 209   233  TKL           Tokelau      Nukunonu        Oceania
# 150   232  NIU              Niue         Alofi        Oceania
# 64    231  FLK  Falkland Islands       Stanley  South America
# 137   230  MSR        Montserrat        Brades  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226            510.0            520.0            564.0            596.0
# 209           1871.0           1827.0           1454.0           1367.0
# 150           1934.0           1942.0           1847.0           1812.0
# 64            3780.0           3747.0           3408.0           3187.0
# 137           4390.0           4500.0           5059.0           4938.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 226            651.0            700.0            733.0            752.0
# ...

# %% [markdown]
# En caso de ser necesario ordenar los datos de manera descendente y para un numero superior de filas, podemos cambiarlo de la siguiente manera

# %%
df.sort_values(by="2022 Population", ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...
